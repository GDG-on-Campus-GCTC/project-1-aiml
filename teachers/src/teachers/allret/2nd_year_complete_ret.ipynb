# %%
# !pip install -U langchain langchain-community langchain-openai pypdf faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.2/111.2 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 69.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 10.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.6/330.6 kB 35.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.8/23.8 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 496.3/496.3 kB 44.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 6.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.2.8
# ...

# %%
# !pip install -U langchain langchain-community langchain-text-splitters

# %%
# !pip install -U pypdf

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 81.9 MB/s eta 0:00:00
# ...

# %%
loader = PyMuPDFLoader("/content/CAALP.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "CAALP or Computer Architecture and Assembly Language Programming",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore = FAISS.from_documents(chunks, embeddings)
# Out:
# /tmp/ipython-input-3737191659.py:26: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
loader = PyMuPDFLoader("/content/DAA.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "DAA OR Design and Analysis of Algorithm",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['8ab2daff-1db8-4be3-9dd5-fc7d82de1eeb',
#  'df1b0116-4c87-4305-b49f-5f8a82ee82a8',
#  'a2e3a922-cf71-48d5-ae3b-30b7244e752c',
#  'e5631c8e-acc4-4896-bdca-dbbe7ab20a9e',
#  '10408786-adf3-4c5e-ab74-3e55ac0723df',
#  'df0df739-0369-4835-99d1-646dbb8d90d3',
#  'c5ddd69c-00a9-404a-8b45-a329ba8e512a',
#  '4ba1150b-c960-4080-9c99-dccc88c53dce',
#  '7897862f-bf55-44ea-8e97-6a0a88464967',
#  '64fd27c5-2a0f-43a9-b5b0-f5c2f1e0f3b1',
#  'b965f37c-140c-4f18-9a73-02183978c961',
#  '1d5b2edf-e737-4ef7-a88a-46c26a3e3387',
#  '87032b36-a7c7-4e28-9407-993cd91d8e55',
#  '1b5b498e-31ce-41ff-acee-df9eb67c275c',
# ...

# %%
loader = PyMuPDFLoader("/content/dsa.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "DSA OR Data Structure and algorithm",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['5876de05-6a58-4120-9799-d29f898a92a6',
#  '7d3bd5af-b805-4bc1-96ba-ec9e8d169bf6',
#  'aa3156a0-64e7-4423-a1a5-0344cfc169bc',
#  'ce4f24b3-bad6-4102-a16c-dd41e127fa6f',
#  '9614a6c0-68af-44c2-9622-0798fc3154b5',
#  '22546a90-51f8-4f6c-8862-5a89d500e30e',
#  'eaae99e7-578c-4ede-953b-4babd1346926',
#  '35fd5f7f-8fba-4e3c-818e-307f33976b34',
#  '358413ca-bf21-46e7-912a-d36a0c30ee23',
#  '301be157-a460-4248-82f0-600368ea522b',
#  '61a6ea9a-901d-4f59-8261-9317461318fc',
#  '1cb7d2e2-1026-416f-843e-aac02d81e860',
#  '06b25fbf-183b-4c1f-90b4-7b451f334c64',
#  'de6617d8-d975-446a-9deb-68bf71f8e191',
# ...

# %%
loader = PyMuPDFLoader("/content/EEA.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "EEA or Engineering Economics and Accounts",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['6f9949b0-4bda-45af-b9c5-aaed7deaad5a',
#  'dcc9e840-bf0c-463c-864d-cee75643172d',
#  '3c980726-aa97-4011-a929-de95952e28ca',
#  'ba34c683-941d-429a-8f30-864ba26672f7',
#  '3bb6c66a-8815-4e22-9f6b-c33b1c6277ae',
#  '38d00658-886c-4837-ac93-fa1d6d0e6984',
#  'b0dd3997-54b0-403f-897e-9fe2612d223b',
#  'a283696c-5798-4b44-85c1-cdb1202455b0',
#  '214bfcbd-4b1a-4bc5-bca0-66d822bac77a',
#  '1ecb20b1-6374-46f1-be84-225adbdca994',
#  '8705e377-0b23-42f4-83f0-cc4b5d60cccc',
#  '9c9b02d3-569e-41b7-998e-b34ebc53e6a2',
#  'b9181e94-23ca-4ec2-823e-afbfd05f1659',
#  'f971da8f-b494-4808-82cb-cad5b048482c',
# ...

# %%
loader = PyMuPDFLoader("/content/OOPS.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "OOPS or Java or Object Oriented Programming",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['e3c1aeda-78f5-4ca1-9215-f46e0246b332',
#  '9acb2f03-5234-47d0-a501-a98d8f5a9bd0',
#  'e3950560-057d-417b-a1d6-4c4e54c91cb2',
#  '7c6f333a-150a-43cd-969f-11d7f824ac57',
#  '664aeb8f-1d73-4d8e-b4f9-3bcc7bd49ff1',
#  'e3e0119c-2b36-46b3-b2a3-7bd075e826c0',
#  '84f0afe6-3679-48cf-950a-551479127f91',
#  '868bcc4d-514a-4065-b983-30a8b53c24b6',
#  '27a67467-066a-4e25-bc58-49a80e715807',
#  'b778b774-3c06-4b59-831f-c5f239b0d69d',
#  'f1332c89-9d2c-4702-9df2-0f36dcecdc43',
#  '4278d27c-4932-43a7-af33-51f24d77e4b3',
#  'de1261d9-d7fa-4cd3-96f7-b27dd0903af6',
#  '883b2302-ed1d-4e95-9cc9-8a01e1dc27e1',
# ...

# %%
loader = PyMuPDFLoader("/content/OS Book Galvin.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "OS or Operating System",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['5fc728d0-8a11-42ec-a40c-3e87db3e6177',
#  '256134b3-e2e1-4e40-a471-cf804ad2f47c',
#  'e35c5bd9-fa9e-4680-9c99-5f33e2c204bd',
#  '0fa2be7f-63da-4978-88c3-f72c7bcd66d1',
#  '22bee9c0-acbb-4596-8461-557c9809e225',
#  'a590e8c8-867b-4486-b902-9f54455bbfd4',
#  'ce91ce33-1fe8-40e6-8855-aab02ada039e',
#  'c51ff343-b87c-49d9-bab5-1c724b070630',
#  'a653a9bf-4309-4fe7-a382-1d428227d161',
#  '6eae26ae-9003-4023-b7e2-2ce068bb5f96',
#  'f9626a5f-4927-42bf-9019-a72f83e3bdcb',
#  '88bd7530-f102-42d1-a352-0242d80889cc',
#  'b8f4e144-8456-4096-bb79-f63133b3532c',
#  'ff16a233-fc6c-4a3f-a6e3-d1ecb4c85811',
# ...

# %%
loader = PyMuPDFLoader("/content/DD.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "DD or Digital Design",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['05354eea-03e7-4ee4-a89f-176c61885189',
#  'a802be19-e833-4a23-8b36-3c58cd2202c7',
#  'e0bdd955-b62f-4c2f-904e-5e7ec3c1d33f',
#  '194c1c6c-0e3b-4529-9102-1a5c5e25f89e',
#  '5fccc75a-4fc2-4d55-b33b-2405b308765b',
#  '9c1ceb1a-63a1-4c82-868c-febe86772cf3',
#  'b0c94253-f76a-4214-b3f9-30986cd9d6ee',
#  'e113e2f6-4eb5-465a-9e60-18cb71ede009',
#  'ba55f64d-4d75-4d41-8eda-be0f37a1edc1',
#  '674782d4-801a-408f-8e33-c55c32c9875a',
#  '166d6589-db67-4df9-a710-ee01dd6a64f5',
#  'da86f12b-9772-47db-b22b-f70a48943a9e',
#  'e86e8fbb-888b-4a03-8476-26ce4e84fe71',
#  '24ce11b4-3739-48a8-9363-272528f2e9f9',
# ...

# %%
loader = PyMuPDFLoader("/content/WT - 2ND YEAR.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "WT OR WEB TECHNOLOGY",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['9445a73d-05d4-430b-8f2d-a38a8f4da0c9',
#  '30ecd9bb-ec76-429e-b833-a90846b63d76',
#  'c9eb3ff7-9720-4a63-88a0-00127af98dd9',
#  '4570b3d6-60c3-49c2-bded-1114cc3df9ee',
#  '4f06ca0f-4226-4f94-a7dd-4d5d9265f442',
#  'fb077c29-2f20-418d-862c-74a4fc4bf6c3',
#  '2ffb53b3-e607-4c3d-ab66-eed7f17e920a',
#  'b359dafd-12c6-4cf3-8873-18f504788777',
#  'e1cec705-588c-4582-b647-f5f306688ad4',
#  '91e03251-f594-4195-b2f9-90fdac51d312',
#  'e4eb1d32-0a7d-41a8-a428-fd158f489cd7',
#  '46b594e8-ee8f-4c10-9341-f1041534d102',
#  '27b352a0-77df-4f68-a002-f7730eb00769',
#  '6d7d63cf-f422-4618-946c-fbbdb2f9ecd8',
# ...

# %%
loader = PyMuPDFLoader("/content/english 2n  year.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "english fro communication ",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['5a704765-3842-43cb-b686-ca24328f3660',
#  'e7e85d36-e955-40c2-bfae-743f05eb234e',
#  '42ba1bae-d04e-40c4-a582-0fd0acd13a53',
#  '24b5943d-4f18-498d-a9d2-ec6f4b897eee',
#  'cebd2afa-5897-416c-831f-5a5d9d04533b',
#  '3d084eaa-4bde-467c-a6e6-128f5dc1c007',
#  'bbdeea89-304f-443c-bf7b-e951230f2e56',
#  'e2a79b7e-0290-40e9-8f75-b929e544c75f',
#  '12f27794-ec17-4a7d-82d6-24557b71a547',
#  '8f06438c-bce2-4452-96ee-6507495cf4a2',
#  '59fbd3d2-4c03-4fe5-85d3-35487bc5208e',
#  'd7508446-560e-4cd4-b443-cd86abab171c',
#  '9196c4d6-ff24-4f0b-9619-701cbe2a6d15',
#  '4ceeeaf3-6356-4019-b763-23a607bf9b2d',
# ...

# %%
loader = PyMuPDFLoader("/content/DBMS DONE.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 2,
        "subject": "SQL and DBMS",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore.add_documents(chunks)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['de910de5-10e3-436d-9212-5ce134dd8b75',
#  '7d574a2e-6cd3-4bce-8f16-a264f5bb5984',
#  '44c92a63-2e46-4c81-a0f3-91bfabd2a39a',
#  'd1b0f989-40ce-4073-a2fe-2958a3202b01',
#  '475f8414-fa5f-4eef-b786-37de13961438',
#  '0e01dfe0-f2a7-48fc-81dc-a4f1f76df39a',
#  'aff36437-bf21-47d1-9486-aa6ec63ef5de',
#  '9dd5d4d9-2cc2-4982-8e77-170e6aaaaf94',
#  'e1a43637-2895-4913-93b5-319225d09c26',
#  '097e5ebc-c71e-487f-a9f6-77b6ad948f5d',
#  '7e650d89-a847-442f-b558-bdfc6780a7ae',
#  '3b32d16a-2312-4ae2-a5da-4cb69b889ba9',
#  '7b8710c1-13fc-4c55-8160-f550262d5ca7',
#  '570ac78f-059a-49bb-a36d-531c9ce095e6',
# ...

# %%
r=vectorstore.as_retriever(search_kwargs={"k":5},search_type="similarity")

# %%
vectorstore.save_local("final_2ndyearret")

# %%
vectorstore.save_local("2nd_year retrive")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
/content/2nd_year_retrive/index.faiss
/content/2nd_year_retrive/index.pkl
# Out:
#   File "/tmp/ipython-input-1592912951.py", line 1
#     content/2nd_year_retrive/index.faiss()
#             ^
# SyntaxError: invalid decimal literal

# %%
# !cp /content/2nd_year_retrive/index.faiss /content/drive/MyDrive/
# !cp /content/2nd_year_retrive/index.pkl /content/drive/MyDrive/
# Out:
# cp: cannot stat '/content/2nd_year_retrive/index.faiss': No such file or directory
# cp: cannot stat '/content/2nd_year_retrive/index.pkl': No such file or directory

# %%
# !cp /content/2nd_year\ retrive/index.faiss /content/drive/MyDrive/

# %%
# !cp /content/2nd_year\ retrive/index.pkl /content/drive/MyDrive/
