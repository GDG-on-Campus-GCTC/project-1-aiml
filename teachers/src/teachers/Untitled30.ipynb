# %%
#!pip install -U pypdf

# %%
#!pip install -U langchain langchain-community langchain-openai pypdf faiss-cpu

# %%
#!pip install -U langchain langchain-community langchain-text-splitters

# %%
"""from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile"c1,   # very strong
    temperature=0.2
)

response = llm.invoke("Explain entropy in simple terms")
print(response.content)"""
# Out:
# Entropy is a concept that can be a bit tricky to understand, but I'll try to break it down in simple terms.
#
# **What is entropy?**
#
# Entropy is a measure of how disorganized or random something is. Imagine you have a clean and tidy room. Everything is in its place, and it's easy to find what you need. This is a state of low entropy.
#
# Now, imagine that same room after a big party. There are clothes scattered all over the floor, empty bottles and cans everywhere, and it's hard to find anything. This is a state of high entropy.
#
# **How does entropy work?**
#
# Entropy always increases over time. This means that things tend to become more disorganized and random as time passes. It's like the room will always get messier if you don't clean it up.
#
# Here are a few examples to illustrate this:
#
# * A deck of cards is organized when it's new, but as you shuffle it, the cards become more random and disorganized (high entropy).
# ...

# %%
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
#!pip install pymupdf

# %%
loader=PyMuPDFLoader("/content/Let_Us_C_-_Yashwant_Kanetkar.pdf")
pages=loader.load()

# %%
total_pages=len(pages)
total_pages
# Out:
# 728

# %%
for page_num,page in enumerate(pages):
  page.page_content=page.page_content.strip()
  page.metadata.update({
      "YEAR":1,
      "subject":"pps or Programming for problem solving",
      "page": page_num+1,
      "total_pages":total_pages
  })

# %%
splitter=RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)
chunks=splitter.split_documents(pages)

# %%
for i , chunk in enumerate(chunks):
  chunk.metadata["chunk_id"]=i

# %%
embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# /tmp/ipython-input-3123569051.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
#! pip install faiss-cpu

# %%
vectorstore=FAISS.from_documents(chunks,embeddings)

# %%
loader = PyMuPDFLoader("/content/Let_Us_C_-_Yashwant_Kanetkar.pdf")
pages = loader.load()

total_pages = len(pages)

for page_num, page in enumerate(pages):
    page.page_content = page.page_content.strip()
    page.metadata.update({
        "YEAR": 1,
        "subject": "PPS or Programming for Problem Solving",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = splitter.split_documents(pages)


for i, chunk in enumerate(chunks):
    chunk.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# 7. Create FAISS vector store
vectorstore = FAISS.from_documents(chunks, embeddings)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
loaders = PyMuPDFLoader("/content/Advanced Engineering Mathematics, 10th Edition by Erwin Kreyszig, In collaboration with Herbert Kreyszig and Edward J. Norminton (z-lib.org).pdf")
pagess = loaders.load()

total_pages = len(pagess)

for page_nums, pager in enumerate(pagess):
    pager.page_content = pager.page_content.strip()
    pager.metadata.update({
        "YEAR": 1,
        "subject": "Mathematics or MVC ",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunkss = splitter.split_documents(pagess)


for i, chunkn in enumerate(chunkss):
    chunkn.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
#vectorstore.add_documents(chunkss)

# %%
r=vectorstore.as_retriever(search_kwargs={"k":5},search_type="similarity")

# %%
loaders = PyMuPDFLoader("/content/AP -.pdf")
pagesr = loaders.load()

total_pages = len(pagesr)

for page_numss, pagerr in enumerate(pagesr):
    pagerr.page_content = pagerr.page_content.strip()
    pagerr.metadata.update({
        "YEAR": 1,
        "subject": "physics or applied physics or semiconductor",
        "page": page_num + 1,
        "total_pages": total_pages
    })

splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunkers = splitter.split_documents(pagesr)


for i, chunknn in enumerate(chunkers):
    chunknn.metadata["chunk_id"] = i

embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
vectorstore.add_documents(chunkers)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ['0887a17c-dc20-48c2-b644-72330c2aaac9',
#  '86ffb3f8-be53-46ce-9a16-e114006b4ecd',
#  '0c5a0aca-c6f5-42bd-a1c8-9c737c40022c',
#  '29a45c6d-bc87-45dc-9b76-2199a5e24478',
#  '69ca110f-b69f-47d1-bed7-60c5946c1d19',
#  '2153dc4b-d315-44e3-b717-661e4989086e',
#  'eb4e8b0d-9995-40a1-a032-f4397ea25052',
#  'c5cb5609-4279-4e7c-988e-f11ec34ba076',
#  '2793d769-ecd0-45a9-a631-91add3851896',
#  'cc5a3204-898e-4db5-8473-062da87479ae',
#  '85130355-45bb-4f42-8dbb-ba51927e7539',
#  '7f360a74-2eea-4fe3-ad0e-26fdd5506aab',
#  '6fd947f6-b9bd-4c9d-aade-b67a034223ec',
#  '69f74555-6a2e-4c79-988c-977fb7ded9da',
# ...

# %%
vectorstore.save_local("first_year_retrival")

# %%
r.invoke("lasers")
# Out:
# [Document(id='a99efd7c-7d07-4ef6-a80a-a75216ec7ee0', metadata={'producer': 'iLovePDF', 'creator': '', 'creationdate': '', 'source': '/content/AP -.pdf', 'file_path': '/content/AP -.pdf', 'total_pages': 76, 'format': 'PDF 1.6', 'title': '', 'author': '', 'subject': 'physics or applied physics or semiconductor', 'keywords': '', 'moddate': '2026-02-04T15:34:12+00:00', 'trapped': '', 'modDate': 'D:20260204153412Z', 'creationDate': '', 'page': 728, 'YEAR': 1, 'chunk_id': 248}, page_content='\uf0d8 Davisson and Germer were experimented the scattering of electrons from the Nickel target.  \n\uf0d8 The scattered electrons are diffracted like X-rays. The apparatus consists of an electron gun. It consists \nof a filament F. If filament  F is heated to high temperature by sending current through it then the \nelectrons are emitted from the filament F. \n\uf0d8 These electrons are accelerated by applying the potential difference V. The electrons are made into \nnarrow beam with the help of two s
# ...
